# %% [markdown]
# # Exercises
#
# Try to use one-liners for 1-3

# %% [markdown]
# ### Exercise #1 <br>
# <p>Filter out all of the empty strings from the list below</p>

# %%
places = [' ', 'Argentina', '  ', 'San Diego', '', '   ', '', 'Boston', 'New York']
# = [Argentina, San Diego, Boston, New York]

list(filter(lambda p: p.strip() != "" , places))
# Out:
# ['Argentina', 'San Diego', 'Boston', 'New York']

# %% [markdown]
# ### Exercise #2 <br>
# <p>Write an anonymous function that sorts this list by the last name...<br><b>Hint: Use the ".sort()" method and access the key"</b></p>

# %%
# .sort(key=)

authors = ["Connor Milliken", "Victor aNisimov", "Andrew P. Garfield", "David HassELHOFF", "Oprah wInfrey"]

sorted(authors, key = lambda n: n.split(" ")[-1].lower())
# Out:
# ['Victor aNisimov',
#  'Andrew P. Garfield',
#  'David HassELHOFF',
#  'Connor Milliken',
#  'Oprah wInfrey']

# %% [markdown]
# ### Exercise #3 <br>
# <p>Convert the list below from Celsius to Farhenheit, using the map function with a lambda...</p>

# %%
places = [('Nassau', 32), ('Boston', 12), ('Los Angeles', 44), ('Miami', 29)]

# HINT: KEEP IN MIND PEMDAS. USE THE CELCIUS - FAHRENHEIT CONVERSION
# F = C * 9/5 + 32
list(map(lambda the_tup: (the_tup[0] , the_tup[1] * 9/5 +32), places))
# Out:
# [('Nassau', 89.6), ('Boston', 53.6), ('Los Angeles', 111.2), ('Miami', 84.2)]

# %% [markdown]
# ### Exercise #4 <br>
# <p>Write a recursive function to perform the fibonacci sequence up to the number passed in.</p>

# %%
#0, 1, 1, 2, 3, 5, 8 
#Fn = Fn-1 + Fn-2
#seed values : f(0) = 0 & f(1) = 1

# %%
def fib_seq(n): 
    if n == 0: 
        return 0 
    elif n == 1 or n==2: 
        return 1
    else:
        return(fib_seq(n - 1)) + (fib_seq(n -2))
    
fib_seq(10)
# Out:
# 55
